# %% [markdown]
# ### Nama : Hudzaifah Alqarani
# ### NIM  : 2109106089
# ### POSTEST 2 KB

# %% [markdown]
# #### import pandas dan dataset

# %%
import pandas as pd

# %% [markdown]
# dataset= pd.read_csv("Drug_clean.csv")

# %% [markdown]
# #### tampilkan isi dataset

# %%
dataset
# Out:
#                      Condition                         Drug  EaseOfUse  \
# 0    Acute Bacterial Sinusitis                  Amoxicillin   3.852353
# 1    Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   3.470000
# 2    Acute Bacterial Sinusitis  Amoxicillin-Pot Clavulanate   3.121429
# 3    Acute Bacterial Sinusitis                   Ampicillin   2.000000
# 4    Acute Bacterial Sinusitis                   Ampicillin   3.250000
# ..                         ...                          ...        ...
# 680   vulvovaginal candidiasis           Miconazole Nitrate   3.465000
# 681   vulvovaginal candidiasis      Miconazole-Skin Clnsr17   4.750000
# 682   vulvovaginal candidiasis      Miconazole-Skin Clnsr17   4.000000
# 683   vulvovaginal candidiasis                  Terconazole   3.525000
# 684   vulvovaginal candidiasis                  Tioconazole   3.852500
#
#      Effective            Form Indication       Price     Reviews  \
# ...

# %% [markdown]
# #### 1. Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
dataset.describe()
# Out:
#         EaseOfUse   Effective         Price      Reviews  Satisfaction
# count  685.000000  685.000000    685.000000   685.000000    685.000000
# mean     3.920038    3.523530    174.211183    82.644410      3.195699
# std      0.894212    0.954126    667.743466   273.281398      1.030442
# min      1.000000    1.000000      4.000000     1.000000      1.000000
# 25%      3.556667    3.000000     15.490000     3.000000      2.575000
# 50%      4.050000    3.600000     49.990000    10.350877      3.200000
# 75%      4.500000    4.110000    145.990000    57.000000      3.901250
# max      5.000000    5.000000  10362.190000  4647.000000      5.000000

# %% [markdown]
# #### 2. Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
dataset.select_dtypes(include=['number']).head(10)
# Out:
#    EaseOfUse  Effective       Price     Reviews  Satisfaction
# 0   3.852353   3.655882   12.590000   86.294118      3.197647
# 1   3.470000   3.290000  287.370000   43.000000      2.590000
# 2   3.121429   2.962857   70.608571  267.285714      2.248571
# 3   2.000000   3.000000   12.590000    1.000000      1.000000
# 4   3.250000   3.000000  125.240000   15.000000      3.000000
# 5   3.000000   3.000000  143.215000    1.000000      3.000000
# 6   4.091667   3.341667   32.100000  490.000000      2.758333
# 7   3.582000   3.458000   99.490000  141.600000      2.780000
# 8   2.895000   3.255000  125.240000   41.000000      2.510000
# 9   2.944444   3.277778  332.630000    3.666667      3.222222

# %% [markdown]
# #### 3. Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya. Tampilkan isi dari dictionary tersebut sebagus mungkin.

# %%
jumlah_seluruh_record = len(dataset)
jumlah_seluruh_attribute = len(dataset.columns)
nama_attribute = list(dataset.columns)
attribute_angka = len( dataset.select_dtypes(include=['number']).columns)
dictionary = {
    'Jumlah record' : jumlah_seluruh_record,
    'Jumlah seluruh attribute' : jumlah_seluruh_attribute,
    'nama - nama attribute' : nama_attribute,
    'Jumlah attribute dengan tipe angka' : attribute_angka
}
for key, value in dictionary.items():
    print(f'{key} : {value}')
# Out:
# Jumlah record : 685
# Jumlah seluruh attribute : 10
# nama - nama attribute : ['Condition', 'Drug', 'EaseOfUse', 'Effective', 'Form', 'Indication', 'Price', 'Reviews', 'Satisfaction', 'Type']
# Jumlah attribute dengan tipe angka : 5

# %% [markdown]
# #### 4. Tampilkan nilai dataset pada baris dimulai dengan 3 digit NIM akhir hingga data terakhir dan kolom ke 4 hingga kolom terakhir menggunakan ke 2 metode slice

# %%
dataset.loc[89:, dataset.columns[3:]]
# Out:
#      Effective            Form Indication   Price     Reviews  Satisfaction  \
# 89    4.000000  Liquid (Drink)   On Label  184.99    1.000000      4.000000
# 90    3.750000          Tablet   On Label  172.99    2.500000      4.000000
# 91    3.470000  Liquid (Drink)   On Label  149.99   62.500000      2.790000
# 92    1.000000           Cream  Off Label   47.99    2.000000      1.000000
# 93    2.333333  Liquid (Drink)  Off Label   59.74    1.333333      2.333333
# ..         ...             ...        ...     ...         ...           ...
# 680   2.770000           Cream   On Label   13.99   19.500000      2.345000
# 681   3.000000           Cream   On Label   13.99    4.000000      3.000000
# 682   1.000000           Other   On Label  125.99    1.000000      1.000000
# 683   3.047500           Cream   On Label   68.99   20.000000      2.717500
# 684   2.022500           Other   On Label   22.99  145.000000      1.827500
#
#        Type
# 89       RX
# 90       RX
# 91       RX
# ...

# %% [markdown]
# #### 5. Tampilkan jumlah label dari semua attribute yang bernilai object (contoh : Jenis Kelamin, Agama).

# %%
attribute_object = dataset.select_dtypes(include=['object']).columns.tolist()
for i in attribute_object :
    print(dataset[i].value_counts())
# Out:
# hypertension                                 101
# Atopic Dermatitis                             67
# fever                                         64
# gastroesophageal reflux disease               54
# Bacterial Urinary Tract Infection             53
# hypercholesterolemia                          32
# hemorrhoids                                   31
# gout                                          31
# endometriosis                                 19
# Pharyngitis due to Streptococcus Pyogenes     19
# back pain                                     17
# diverticulitis of gastrointestinal tract      16
# Bacterial Conjunctivitis                      16
# flatulence                                    15
# depression                                    15
# edema                                         15
# prevention of cerebrovascular accident        14
# Acute Bacterial Sinusitis                     14
# vertigo                                       13
# ...
